# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from cartopy import crs as ccrs
from cartopy import feature as cfeature

# %%
#This will be the lon and lat for the box (NW, NE, SE, SW, NW)
box = [[49,-108], [49,-87], [32,-87], [32,-108],[49,-108]]
df = pd.DataFrame(box, columns = ['lat', 'lon'])
blat = df['lat'].astype(float)
blon = df['lon'].astype(float)

south_box2 = [[40,-108], [40,-87], [30,-87], [30,-108],[40,-108]]
df2 = pd.DataFrame(south_box2, columns = ['lat', 'lon'])
blat2 = df2['lat'].astype(float)
blon2 = df2['lon'].astype(float)

north_box3 = [[50,-108], [50,-87], [40,-87], [40,-108],[50,-108]]
df3 = pd.DataFrame(north_box3, columns = ['lat', 'lon'])
blat3 = df3['lat'].astype(float)
blon3 = df3['lon'].astype(float)

box4 = [[47,-103], [47,-92], [38,-92], [38,-103],[47,-103]]
df4 = pd.DataFrame(box4, columns = ['lat', 'lon'])
blat4 = df4['lat'].astype(float)
blon4 = df4['lon'].astype(float)

box5 = [[38.5,-103], [38.5,-93], [30,-93], [30,-103],[38.5,-103]]
df5 = pd.DataFrame(box5, columns = ['lat', 'lon'])
blat5 = df5['lat'].astype(float)
blon5 = df5['lon'].astype(float)

# %%
# Set the domain for defining the plot region.BOX1
latN = 50
latS = 20
lonW = -125.0
lonE = -65.0
cLat = (latN + latS)/2
cLon = (lonW + lonE )/2

res = '50m'
proj = ccrs.LambertConformal(central_longitude=cLon, central_latitude=cLat)

fig = plt.figure(figsize=(18,12),dpi=150)
ax = fig.add_subplot(1,1,1,projection=proj)
ax.set_extent ([lonW,lonE,latS,latN])
ax.add_feature (cfeature.LAND.with_scale(res))
ax.add_feature (cfeature.OCEAN.with_scale(res))
ax.add_feature(cfeature.COASTLINE.with_scale(res))
ax.add_feature (cfeature.LAKES.with_scale(res))
ax.add_feature (cfeature.STATES.with_scale(res))
ax.set_title ('Area Extent for COA February 2021')
ax.plot(blon,blat, color='red', linewidth=5,transform=ccrs.PlateCarree())

# %%
# Set the domain for defining the plot region. BOX2
latN = 50
latS = 20
lonW = -125.0
lonE = -65.0
cLat = (latN + latS)/2
cLon = (lonW + lonE )/2

res = '50m'
proj = ccrs.LambertConformal(central_longitude=cLon, central_latitude=cLat)

fig = plt.figure(figsize=(18,12),dpi=150)
ax = fig.add_subplot(1,1,1,projection=proj)
ax.set_extent ([lonW,lonE,latS,latN])
ax.add_feature (cfeature.LAND.with_scale(res))
ax.add_feature (cfeature.OCEAN.with_scale(res))
ax.add_feature(cfeature.COASTLINE.with_scale(res))
ax.add_feature (cfeature.LAKES.with_scale(res))
ax.add_feature (cfeature.STATES.with_scale(res))
ax.set_title ('Southern Box Extent for COA FEB 2021', size=30)
ax.plot(blon2,blat2, color='red', linewidth=5,transform=ccrs.PlateCarree())

# %%
# Set the domain for defining the plot region.
latN = 50
latS = 20
lonW = -125.0
lonE = -65.0
cLat = (latN + latS)/2
cLon = (lonW + lonE )/2

res = '50m'
proj = ccrs.LambertConformal(central_longitude=cLon, central_latitude=cLat)

fig = plt.figure(figsize=(18,12),dpi=150)
ax = fig.add_subplot(1,1,1,projection=proj)
ax.set_extent ([lonW,lonE,latS,latN])
ax.add_feature (cfeature.LAND.with_scale(res))
ax.add_feature (cfeature.OCEAN.with_scale(res))
ax.add_feature(cfeature.COASTLINE.with_scale(res))
ax.add_feature (cfeature.LAKES.with_scale(res))
ax.add_feature (cfeature.STATES.with_scale(res))
ax.set_title ('Northern Box Extent for COA FEB 2021')
ax.plot(blon3,blat3, color='red', linewidth=5,transform=ccrs.PlateCarree())

# %%
# Set the domain for defining the plot region.
latN = 50
latS = 20
lonW = -125.0
lonE = -65.0
cLat = (latN + latS)/2
cLon = (lonW + lonE )/2

res = '50m'
proj = ccrs.LambertConformal(central_longitude=cLon, central_latitude=cLat)

fig = plt.figure(figsize=(18,12),dpi=150)
ax = fig.add_subplot(1,1,1,projection=proj)
ax.set_extent ([lonW,lonE,latS,latN])
ax.add_feature (cfeature.LAND.with_scale(res))
ax.add_feature (cfeature.OCEAN.with_scale(res))
ax.add_feature(cfeature.COASTLINE.with_scale(res))
ax.add_feature (cfeature.LAKES.with_scale(res))
ax.add_feature (cfeature.STATES.with_scale(res))
ax.set_title ('Box Extent for COA FEB 2021')
ax.plot(blon5,blat5, color='red', linewidth=5,transform=ccrs.PlateCarree())
